# %% [markdown]
# # My first notebook

# %%
from load_place import create_net_file_from
from ga import run_genetic_algorithm
from problem_definition import ProblemDefinition
import random

# %%
place_name = "Borá, Brazil"
random.seed(100)
file_name = create_net_file_from(place_name)
# Out:
# /home/njoppi2/.local/lib/python3.8/site-packages/osmnx/utils_geo.py:335: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for polygon in geometry:
# /home/njoppi2/.local/lib/python3.8/site-packages/osmnx/utils_geo.py:426: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# /home/njoppi2/.local/lib/python3.8/site-packages/osmnx/utils_geo.py:426: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# /home/njoppi2/.local/lib/python3.8/site-packages/networkx/readwrite/pajek.py:75: UserWarning: Node attribute street_count is not processed. Non-string attribute.
#   warnings.warn(
# /home/njoppi2/.local/lib/python3.8/site-packages/networkx/readwrite/pajek.py:93: UserWarning: Edge attribute osmid is not processed. Non-string attribute.
#   warnings.warn(
# /home/njoppi2/.local/lib/python3.8/site-packages/networkx/readwrite/pajek.py:93: UserWarning: Edge attribute length is not processed. Non-string attribute.
#   warnings.warn(

# %%
problem = ProblemDefinition(file_name)

# %%
best_individual = run_genetic_algorithm(problem, 0, dirName=None)

#create PNG for best individual in folder

# %%
print(best_individual.fitness)
best_individual.printDesign(plot=True, dirName=None)
# Out:
# 14.350929550349056
